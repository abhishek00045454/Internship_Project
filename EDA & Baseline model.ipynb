# %% [markdown]
# ## Exploring the credit card fraud dataset
#
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %%
import pandas as pd

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539  \
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
 df['Class'].value_counts(normalize=True)*100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
y = df['Class']
X = df.drop(['Class', 'Amount','Time'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (256326, 28)
# X_test: (28481, 28)
# y_train: (256326,)
# y_test: (28481,)

# %%
import numpy as np

print("Fraud in y_train:", len(np.where(y_train==1)[0]))
print("Fraud in y_test:", len(np.where(y_test==1)[0]))
# Out:
# Fraud in y_train: 443
# Fraud in y_test: 49

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[28426,     6],
#        [   15,    34]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

LABELS = ['Normal','Fraud']

conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d")

plt.title("Confusion matrix")
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# #### Improve Logistic regression model using hyperparamater tuning

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight="balanced")

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d")

plt.title("Confusion matrix")
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# In above results, number of correctly detected frauds are increased from the baseline model (34 -> 45), however the number of false positives are increased to 775 from just 6. Actual frauds predicted to be normal are now decreased to 4 from 15.

# %%
model = LogisticRegression(class_weight={0:1, 1:50})

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d")

plt.title("Confusion matrix")
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# One can see above results are much better than previous results where false positives were 775 which are now reduced to just 55!. Also we just miss out only one true positive (44 now, previos 45)

# %%
model.classes_
# Out:
# array([0, 1])

# %%
model.coef_
# Out:
# array([[ 0.11077592, -0.06859069, -0.01967696,  0.88409344,  0.09144915,
#         -0.18473897,  0.05203225, -0.36027874, -0.1543006 , -0.61276151,
#          0.23644341, -0.58795584, -0.39928999, -0.67522941, -0.11132962,
#         -0.42065113, -0.09667066, -0.03722182, -0.09650186, -0.12984166,
#          0.29407768,  0.52342799, -0.18790098,  0.00292142,  0.00887645,
#         -0.42029811, -0.13369595,  0.03408903]])

# %%
model.coef_.shape
# Out:
# (1, 28)

# %%
model.intercept_
# Out:
# array([-5.61540575])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.98667522, 0.01332478],
#        [0.99558961, 0.00441039],
#        [0.99587779, 0.00412221],
#        ...,
#        [0.99220802, 0.00779198],
#        [0.99792357, 0.00207643],
#        [0.994318  , 0.005682  ]])

# %% [markdown]
# #### SHAP

# %%
#!pip install shap

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
explainer = shap.LinearExplainer(model, X_train)
shap_values = explainer.shap_values(X)
shap.summary_plot(shap_values, X)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
